# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import datetime 
import seaborn as sns

# %%
# setup file path
clipper_file = "C:/Users/Carlos.Maqueda/Desktop/Python/Clipper Global Crude Full History.csv"

# %%
# read csv file
clipper_df = pd.read_csv(clipper_file, low_memory=False)
clipper_df.head(5)
# Out:
#              vessel vessel_flag vessel_class      imo            grade  \
# 0    Elka Vassiliki      GREECE      Aframax  9249104  BRAZILIAN CRUDE
# 1       Kun Lun San   SINGAPORE          FSO  9534028      OMAN EXPORT
# 2          Britanis      GREECE         VLCC  9227481              DAS
# 3          Britanis      GREECE         VLCC  9227481              DAS
# 4  Aquarius Voyager     BAHAMAS         VLCC  9289491       ARAB LIGHT
#
#           grade_country   grade_region grade_api grade_sulfur   load_date  \
# 0                BRAZIL  LATIN AMERICA    medium      unknown  2015-05-09
# 1                  OMAN      ARAB GULF    medium         sour  2015-09-29
# 2  UNITED ARAB EMIRATES      ARAB GULF     light         sour  2015-10-01
# 3  UNITED ARAB EMIRATES      ARAB GULF     light         sour  2015-10-01
# 4          SAUDI ARABIA      ARAB GULF     light         sour  2015-10-02
#
#        ...      lat lon course speed draught ais_timestamp storage  \
# 0      ...      NaN NaN    NaN   NaN     NaN           NaN      No
# 1      ...      NaN NaN    NaN   NaN     NaN           NaN      No
# 2      ...      NaN NaN    NaN   NaN     NaN           NaN      No
# 3      ...      NaN NaN    NaN   NaN     NaN           NaN      No
# 4      ...      NaN NaN    NaN   NaN     NaN           NaN      No
#
#   storage_zone distance_traveled     ton_miles
# 0          NaN       1739.767799  1.555610e+08
# 1          NaN       5826.662802  1.604575e+09
# 2          NaN       7028.726292  9.148161e+08
# 3          NaN       7020.466892  9.137411e+08
# 4          NaN      42144.060442  1.684756e+09
#
# [5 rows x 68 columns]

# %%
# select only needed columns
clipper_df = clipper_df[['vessel_class',
 'load_date',
 'load_port',
 'load_country',
 'load_region',
 'load_area',
 'load_area_descr',
 'offtake_date',
 'offtake_port',
 'offtake_country',
 'offtake_region',
 'offtake_area',
 'offtake_area_descr',
 'bbls','vessel_dwt', 
 'distance_traveled', 
 'ton_miles']]
clipper_df.head(5)
# Out:
#   vessel_class   load_date      load_port          load_country  \
# 0      Aframax  2015-05-09   SAO SEBASTIO                BRAZIL
# 1          FSO  2015-09-29  MINA AL FAHAL                  OMAN
# 2         VLCC  2015-10-01            DAS  UNITED ARAB EMIRATES
# 3         VLCC  2015-10-01            DAS  UNITED ARAB EMIRATES
# 4         VLCC  2015-10-02     RAS TANURA          SAUDI ARABIA
#
#      load_region load_area           load_area_descr offtake_date  \
# 0  LATIN AMERICA      ECSA  East Coast South America   2016-03-15
# 1      ARAB GULF        AG                 Arab Gulf   2016-01-31
# 2      ARAB GULF        AG                 Arab Gulf   2016-01-15
# 3      ARAB GULF        AG                 Arab Gulf   2016-01-12
# 4      ARAB GULF        AG                 Arab Gulf   2016-04-02
#
#      offtake_port offtake_country offtake_region offtake_area  \
# 0  ANGRA DOS REIS          BRAZIL  LATIN AMERICA         ECSA
# 1         QINGDAO           CHINA      EAST ASIA         CH-N
# 2           CHIBA           JAPAN      EAST ASIA          JPN
# 3        KAWASAKI           JAPAN      EAST ASIA          JPN
# 4      EL SEGUNDO   UNITED STATES  NORTH AMERICA         USWC
#
#          offtake_area_descr     bbls  vessel_dwt  distance_traveled  \
# 0  East Coast South America   623998     94143.0        1739.767799
# 1               China North  1996000    318757.0        5826.662802
# 2                     Japan   987500    304732.0        7028.726292
# 3                     Japan   987500    304732.0        7020.466892
# 4             US West Coast   293000    320821.0       42144.060442
#
#       ton_miles
# 0  1.555610e+08
# 1  1.604575e+09
# 2  9.148161e+08
# 3  9.137411e+08
# 4  1.684756e+09

# %%
# convert datatype of the load date to datetime
clipper_df['load_date'] = pd.to_datetime(clipper_df['load_date'])

# %%
# convert datatype of the offtake date to datetime
clipper_df['offtake_date'] = pd.to_datetime(clipper_df['offtake_date'])

# %%
# check to see null values present in offtake, drop if true
clipper_df['offtake_area'].isnull().values.any()
clipper_df.dropna(how='any')
clipper_df.head(5)
# Out:
#   vessel_class  load_date      load_port          load_country    load_region  \
# 0      Aframax 2015-05-09   SAO SEBASTIO                BRAZIL  LATIN AMERICA
# 1          FSO 2015-09-29  MINA AL FAHAL                  OMAN      ARAB GULF
# 2         VLCC 2015-10-01            DAS  UNITED ARAB EMIRATES      ARAB GULF
# 3         VLCC 2015-10-01            DAS  UNITED ARAB EMIRATES      ARAB GULF
# 4         VLCC 2015-10-02     RAS TANURA          SAUDI ARABIA      ARAB GULF
#
#   load_area           load_area_descr offtake_date    offtake_port  \
# 0      ECSA  East Coast South America   2016-03-15  ANGRA DOS REIS
# 1        AG                 Arab Gulf   2016-01-31         QINGDAO
# 2        AG                 Arab Gulf   2016-01-15           CHIBA
# 3        AG                 Arab Gulf   2016-01-12        KAWASAKI
# 4        AG                 Arab Gulf   2016-04-02      EL SEGUNDO
#
#   offtake_country offtake_region offtake_area        offtake_area_descr  \
# 0          BRAZIL  LATIN AMERICA         ECSA  East Coast South America
# 1           CHINA      EAST ASIA         CH-N               China North
# 2           JAPAN      EAST ASIA          JPN                     Japan
# 3           JAPAN      EAST ASIA          JPN                     Japan
# 4   UNITED STATES  NORTH AMERICA         USWC             US West Coast
#
#       bbls  vessel_dwt  distance_traveled     ton_miles
# 0   623998     94143.0        1739.767799  1.555610e+08
# 1  1996000    318757.0        5826.662802  1.604575e+09
# 2   987500    304732.0        7028.726292  9.148161e+08
# 3   987500    304732.0        7020.466892  9.137411e+08
# 4   293000    320821.0       42144.060442  1.684756e+09

# %%
# grouby vessel class
clipper_nonull_df.groupby(['vessel_class'])
clipper_nonull_df.head(5)
# Out:
#   vessel_class   load_date      load_port          load_country  \
# 0      Aframax  2015-05-09   SAO SEBASTIO                BRAZIL
# 1          FSO  2015-09-29  MINA AL FAHAL                  OMAN
# 2         VLCC  2015-10-01            DAS  UNITED ARAB EMIRATES
# 3         VLCC  2015-10-01            DAS  UNITED ARAB EMIRATES
# 4         VLCC  2015-10-02     RAS TANURA          SAUDI ARABIA
#
#      load_region load_area           load_area_descr offtake_date  \
# 0  LATIN AMERICA      ECSA  East Coast South America   2016-03-15
# 1      ARAB GULF        AG                 Arab Gulf   2016-01-31
# 2      ARAB GULF        AG                 Arab Gulf   2016-01-15
# 3      ARAB GULF        AG                 Arab Gulf   2016-01-12
# 4      ARAB GULF        AG                 Arab Gulf   2016-04-02
#
#      offtake_port offtake_country offtake_region offtake_area  \
# 0  ANGRA DOS REIS          BRAZIL  LATIN AMERICA         ECSA
# 1         QINGDAO           CHINA      EAST ASIA         CH-N
# 2           CHIBA           JAPAN      EAST ASIA          JPN
# 3        KAWASAKI           JAPAN      EAST ASIA          JPN
# 4      EL SEGUNDO   UNITED STATES  NORTH AMERICA         USWC
#
#          offtake_area_descr     bbls  vessel_dwt  distance_traveled  \
# 0  East Coast South America   623998     94143.0        1739.767799
# 1               China North  1996000    318757.0        5826.662802
# 2                     Japan   987500    304732.0        7028.726292
# 3                     Japan   987500    304732.0        7020.466892
# 4             US West Coast   293000    320821.0       42144.060442
#
#       ton_miles
# 0  1.555610e+08
# 1  1.604575e+09
# 2  9.148161e+08
# 3  9.137411e+08
# 4  1.684756e+09

# %%
# add week, month, year columns
week = clipper_df['offtake_date'].dt.week
clipper_df['week'] = week

month = clipper_df['offtake_date'].dt.month
clipper_df['month'] = month

year = clipper_df['offtake_date'].dt.year
clipper_df['year'] = year

# %%
clipper_df.head()
# Out:
#   vessel_class  load_date      load_port          load_country    load_region  \
# 0      Aframax 2015-05-09   SAO SEBASTIO                BRAZIL  LATIN AMERICA
# 1          FSO 2015-09-29  MINA AL FAHAL                  OMAN      ARAB GULF
# 2         VLCC 2015-10-01            DAS  UNITED ARAB EMIRATES      ARAB GULF
# 3         VLCC 2015-10-01            DAS  UNITED ARAB EMIRATES      ARAB GULF
# 4         VLCC 2015-10-02     RAS TANURA          SAUDI ARABIA      ARAB GULF
#
#   load_area           load_area_descr offtake_date    offtake_port  \
# 0      ECSA  East Coast South America   2016-03-15  ANGRA DOS REIS
# 1        AG                 Arab Gulf   2016-01-31         QINGDAO
# 2        AG                 Arab Gulf   2016-01-15           CHIBA
# 3        AG                 Arab Gulf   2016-01-12        KAWASAKI
# 4        AG                 Arab Gulf   2016-04-02      EL SEGUNDO
#
#   offtake_country offtake_region offtake_area        offtake_area_descr  \
# 0          BRAZIL  LATIN AMERICA         ECSA  East Coast South America
# 1           CHINA      EAST ASIA         CH-N               China North
# 2           JAPAN      EAST ASIA          JPN                     Japan
# 3           JAPAN      EAST ASIA          JPN                     Japan
# 4   UNITED STATES  NORTH AMERICA         USWC             US West Coast
#
#       bbls  vessel_dwt  distance_traveled     ton_miles  week  month  year
# 0   623998     94143.0        1739.767799  1.555610e+08    11      3  2016
# 1  1996000    318757.0        5826.662802  1.604575e+09     4      1  2016
# 2   987500    304732.0        7028.726292  9.148161e+08     2      1  2016
# 3   987500    304732.0        7020.466892  9.137411e+08     2      1  2016
# 4   293000    320821.0       42144.060442  1.684756e+09    13      4  2016
